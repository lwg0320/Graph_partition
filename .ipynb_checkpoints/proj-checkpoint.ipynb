# %% [markdown]
# # Experimentation

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
import networkx as nx
from parse import *
from utils  import *
from pulp import *
from math import comb
import gurobipy as gp
from gurobipy import GRB

# %%
sample_input = pd.read_csv("samples/10.in", header = None)
sample_output = np.array(pd.read_csv("samples/10.out", header = None))

# %%
graph, budget = read_input_file("samples/10.in")

# %%
pos = nx.kamada_kawai_layout(graph)  # positions for all nodes
# nx.draw(graph, pos, with_labels=True)

# %%
# prob = LpProblem("proj",LpMaximize)

# %%
# # edges 
# # Add diagonal variables such that (1,1) have 0 happiness and sadness
# edges = np.array(["e01","e02","e03","e12","e13","e23"])
# weights = [9.2, 5.4, 2.123, 75.4,18,87]*3
# sad = [3,40.8,98,8,57.904,9.4]*3
# d = {}
# for j in range(3):
#     for i in edges:
#         d["{0}_{1}".format(i,j)] = LpVariable("{0}_{1}".format(i,j), lowBound = 0, upBound=1, cat="Integer")
# edges = list(d.values())
# # e11 = LpVariable("{0}_{1}".format(i,j), lowBound = 0, upBound=1, cat="Integer")
# # e22 = LpVariable("{0}_{1}".format(i,j), lowBound = 0, upBound=1, cat="Integer")
# # e33 = LpVariable("{0}_{1}".format(i,j), lowBound = 0, upBound=1, cat="Integer")

# %%
# # vertices 
# vertices = ["v0", "v1", "v2", "v3"]
# d = {}
# for j in range(3):
#     for i in vertices:
#         d["{0}_{1}".format(i,j)] = LpVariable("{0}_{1}".format(i,j), lowBound = 0, cat="Integer")
# vertices = list(d.values())
# vertices

# %%
# prob += sum(edges[i] * weights[i] for i in range(len(weights)))

# %%
# prob += sum(edges[i] for i in [0,6,12]) == 1
# prob += sum(edges[i] for i in [1,7,13]) == 1
# prob += sum(edges[i] for i in [2,8,14]) == 1
# prob += sum(edges[i] for i in [3,9,15]) == 1
# prob += sum(edges[i] for i in [4,10,16]) == 1
# prob += sum(edges[i] for i in [5,11,17]) == 1

# %%
# prob += sum(edges[i] * sad[i] for i in range(6)) <= 42.314/3
# prob += sum(edges[i] * sad[i] for i in range(6,12)) <= 42.314/3
# prob += sum(edges[i] * sad[i] for i in range(12,18)) <= 42.314/3

# prob += sum(vertices[i] for i in [0,4,8]) == 1 
# prob += sum(vertices[i] for i in [1,5,9]) == 1
# prob += sum(vertices[i] for i in [2,6,10]) == 1
# prob += sum(vertices[i] for i in [3,7,11]) == 1


# # Linearization of quadratic variables (eijk =vik * vjk)

# %%
# prob

# %%
# prob.solve()
# for v in prob.variables():
#     print(v.name, "=", v.varValue)

# %% [markdown]
# # Scale

# %% [markdown]
# Assumptions
# - Fewer rooms imply higher happiness scores in expectation

# %%
sample_input = pd.read_csv("samples/10.in", header = None)
n = int(list(sample_input[0])[0])
s_max = float(list(sample_input[0])[1])
K = 3

# %%
# Parsing input data 
df = sample_input
df = pd.DataFrame([x.split() for x in df[0].tolist() ])
df = df.loc[2:,:]
df["i"] = df.loc[:,0]
df["j"] = df.loc[:,1]
df["sadness"] = df.loc[:,3]
df["happiness"] = df.loc[:,2]
df = df[["i", "j", "sadness", "happiness"]]

# %%
i_id = [int(i) for i in list(df["i"])]
j_id = [int(i) for i in list(df["j"])]
sadness = [float(i) for i in list(df["sadness"])]*K
happiness = [float(i) for i in list(df["happiness"])]*K

sadness_1 = [float(i) for i in list(df["sadness"])]
happiness_1 = [float(i) for i in list(df["happiness"])]
len(sadness) == len(happiness)
# Out:
# True

# %%
prob = LpProblem("solver",LpMaximize)

# %%
# edges 
d_e = {}
for k in range(K):
    for i in range(comb(n,2)):
        d_e["e_{0}_{1}_{2}".format(i_id[i],j_id[i],k)] = LpVariable("e_{0}_{1}_{2}".format(i_id[i],j_id[i],k), cat="Binary")
edges_1 = list(d_e.values())


# Create another edge array with different sort
edges_2 = [d_e.get(i) for i in sorted(d_e.keys(), key=lambda x: (x[2], x[4]))]

# Create another edge array for constraint 4 
edges_3 = [d_e.get(i) for i in sorted(d_e.keys(), key=lambda x: (x[2], x[6]))]

# Check
len(edges_1) == comb(n,2)*K
# Out:
# True

# %%
# vertices 
d_v = {}
for j in range(K):
    for i in range(n):
        d_v["v_{0}_{1}".format(i,j)] = LpVariable("v_{0}_{1}".format(i,j), cat="Binary")
vertices_1 = list(d_v.values())

# Create another edge array with different sort
vertices_2 = [d_v.get(i) for i in sorted(d_v.keys(), key=lambda x: x[2])]

# Check
len(vertices_1) == n*K
# Out:
# True

# %%
# Linearization of quadratic variables 1 
v_list = np.array(np.array_split(vertices_1, K)).tolist()
v_big = []
for i in range(K):
    j = 0
    while j != n:
        for _ in range(j,n-1):
            v_big.append(v_list[i][j])
        j += 1
        
print(len(edges_1) == len(v_big))
# Out:
# True

# %%
# Linearization of quadratic variables 2
v_list_2 = [i[1:] for i in v_list]
v_big_2 = []
for h in range(K):
    j = 0
    while j != n:
        for i in range(j,n-1):
            v_big_2.append(v_list_2[h][i])
        j += 1
        i = j
print(len(edges_1) == len(v_big_2))
# Out:
# True

# %% [markdown]
# ## Naive Solver

# %%
# Objective function 
prob += sum(edges_1[i] * happiness[i] for i in range(len(happiness)))

# %%
# # Not sure if we need this constraint now 
# # Constraint 1 
# constraint_2 = [sum(edges_1[i:i + K]) for i in range(0, len(edges_1), K)]
# for i in range(len(constraint_3)):
#     prob += constraint_2[i] == 1

# %%
# Constraint 2
# Each rooms has sadness levels <= s_max / K 
aa = []
h = 0
for i in range(K):
    for j in range(comb(n,2)):
        aa.append(edges_1[h] * sadness_1[j])
        h += 1

constraint_2 = [sum(aa[i:i+ comb(n,2)]) for i in range(0, len(aa), comb(n,2))]
for i in range(len(constraint_2)):
    prob += constraint_2[i] <= s_max / K

# %%
# Constraint 3
# Each person belongs to only one room
constraint_3 = [sum(vertices_2[i:i + K]) for i in range(0, len(vertices_2), K)]
for i in range(len(constraint_3)):
    prob += constraint_3[i] == 1

# %%
# Linearization of quadratic variables
# Constraint 4.1

for i in range(len(edges_1)):
    prob += edges_1[i] <= v_big[i]
    
# Constraint 4.2
for i in range(len(edges_1)):
    prob += edges_1[i] <= v_big_2[i]


# Constraint 4.3
for i in range(len(edges_1)):
    prob += edges_1[i] >= v_big[i] + v_big_2[i] - 1 
    
# # Constraint 4'
# for i in range(len(edges_1)):
#     prob += edges_1[i] == v_big[i] * v_big_2[i]

# %%
path = "/Users/smeetpatel/Library/gurobi.lic"
solver = GUROBI_CMD(path)

# %%
prob
# Out:
# solver:
# MAXIMIZE
# 8.0*e_0_1_0 + 8.0*e_0_1_1 + 8.0*e_0_1_2 + 9.0*e_0_2_0 + 9.0*e_0_2_1 + 9.0*e_0_2_2 + 8.0*e_0_3_0 + 8.0*e_0_3_1 + 8.0*e_0_3_2 + 4.0*e_0_4_0 + 4.0*e_0_4_1 + 4.0*e_0_4_2 + 4.0*e_0_5_0 + 4.0*e_0_5_1 + 4.0*e_0_5_2 + 3.0*e_0_6_0 + 3.0*e_0_6_1 + 3.0*e_0_6_2 + 3.0*e_0_7_0 + 3.0*e_0_7_1 + 3.0*e_0_7_2 + 8.0*e_0_8_0 + 8.0*e_0_8_1 + 8.0*e_0_8_2 + 7.0*e_0_9_0 + 7.0*e_0_9_1 + 7.0*e_0_9_2 + 6.0*e_1_2_0 + 6.0*e_1_2_1 + 6.0*e_1_2_2 + 7.0*e_1_3_0 + 7.0*e_1_3_1 + 7.0*e_1_3_2 + 8.0*e_1_4_0 + 8.0*e_1_4_1 + 8.0*e_1_4_2 + 3.0*e_1_5_0 + 3.0*e_1_5_1 + 3.0*e_1_5_2 + 9.0*e_1_6_0 + 9.0*e_1_6_1 + 9.0*e_1_6_2 + 9.0*e_1_7_0 + 9.0*e_1_7_1 + 9.0*e_1_7_2 + 9.0*e_1_8_0 + 9.0*e_1_8_1 + 9.0*e_1_8_2 + 9.0*e_1_9_0 + 9.0*e_1_9_1 + 9.0*e_1_9_2 + 5.0*e_2_3_0 + 5.0*e_2_3_1 + 5.0*e_2_3_2 + 9.0*e_2_4_0 + 9.0*e_2_4_1 + 9.0*e_2_4_2 + 2.0*e_2_5_0 + 2.0*e_2_5_1 + 2.0*e_2_5_2 + 3.0*e_2_6_0 + 3.0*e_2_6_1 + 3.0*e_2_6_2 + 9.0*e_2_7_0 + 9.0*e_2_7_1 + 9.0*e_2_7_2 + 2.0*e_2_8_0 + 2.0*e_2_8_1 + 2.0*e_2_8_2 + 4.0*e_2_9_0 + 4.0*e_2_9_1 + 4.0*e_2_9_2 + 8.0*e_3_4_0 + 8.0*e_3_4_1 + 8.0*e_3_4_2 + 4.0*e_3_5_0 + 4.0*e_3_5_1 + 4.0*e_3_5_2 + 3.0*e_3_6_0 + 3.0*e_3_6_1 + 3.0*e_3_6_2 + 7.0*e_3_7_0 + 7.0*e_3_7_1 + 7.0*e_3_7_2 + 9.0*e_3_8_0 + 9.0*e_3_8_1 + 9.0*e_3_8_2 + 2.0*e_3_9_0 + 2.0*e_3_9_1 + 2.0*e_3_9_2 + 4.0*e_4_5_0 + 4.0*e_4_5_1 + 4.0*e_4_5_2 + 10.0*e_4_6_0 + 10.0*e_4_6_1 + 10.0*e_4_6_2 + 6.0*e_4_7_0 + 6.0*e_4_7_1 + 6.0*e_4_7_2 + 9.0*e_4_8_0 + 9.0*e_4_8_1 + 9.0*e_4_8_2 + 5.0*e_4_9_0 + 5.0*e_4_9_1 + 5.0*e_4_9_2 + 3.0*e_5_6_0 + 3.0*e_5_6_1 + 3.0*e_5_6_2 + 4.0*e_5_7_0 + 4.0*e_5_7_1 + 4.0*e_5_7_2 + 9.0*e_5_8_0 + 9.0*e_5_8_1 + 9.0*e_5_8_2 + 3.0*e_5_9_0 + 3.0*e_5_9_1 + 3.0*e_5_9_2 + 8.0*e_6_7_0 + 8.0*e_6_7_1 + 8.0*e_6_7_2 + 4.0*e_6_8_0 + 4.0*e_6_8_1 + 4.0*e_6_8_2 + 4.0*e_6_9_0 + 4.0*e_6_9_1 + 4.0*e_6_9_2 + 2.0*e_7_8_0 + 2.0*e_7_8_1 + 2.0*e_7_8_2 + 6.0*e_7_9_0 + 6.0*e_7_9_1 + 6.0*e_7_9_2 + 8.0*e_8_9_0 + 8.0*e_8_9_1 + 8.0*e_8_9_2 + 0.0
# SUBJECT TO
# _C1: 6.591 e_0_1_0 + 8.182 e_0_2_0 + 9.244 e_0_3_0 + 6.899 e_0_4_0
#  + 9.085 e_0_5_0 + 9.371 e_0_6_0 + 6.435 e_0_7_0 + 7.641 e_0_8_0
#  + 9.514 e_0_9_0 + 9.395 e_1_2_0 + 6.915 e_1_3_0 + 8.81 e_1_4_0
#  + 8.972 e_1_5_0 + 9.405 e_1_6_0 + 8.522 e_1_7_0 + 7.448 e_1_8_0
#  + 8.435 e_1_9_0 + 8.883 e_2_3_0 + 6.78 e_2_4_0 + 7.236 e_2_5_0
#  + 6.769 e_2_6_0 + 8.748 e_2_7_0 + 8.99 e_2_8_0 + 8.91 e_2_9_0 + 4.629 e_3_4_0
#  + 9.123 e_3_5_0 + 3.844 e_3_6_0 + 6.833 e_3_7_0 + 4.66 e_3_8_0
#  + 7.756 e_3_9_0 + 6.77 e_4_5_0 + 3.833 e_4_6_0 + 9.197 e_4_7_0
#  + 4.639 e_4_8_0 + 7.008 e_4_9_0 + 6.761 e_5_6_0 + 8.976 e_5_7_0
#  + 9.112 e_5_8_0 + 8.066 e_5_9_0 + 7.193 e_6_7_0 + 5.058 e_6_8_0
#  + 7.003 e_6_9_0 + 9.49 e_7_8_0 + 7.362 e_7_9_0 + 7.29 e_8_9_0
#  <= 26.6666666667
#
# _C2: 6.591 e_0_1_1 + 8.182 e_0_2_1 + 9.244 e_0_3_1 + 6.899 e_0_4_1
#  + 9.085 e_0_5_1 + 9.371 e_0_6_1 + 6.435 e_0_7_1 + 7.641 e_0_8_1
#  + 9.514 e_0_9_1 + 9.395 e_1_2_1 + 6.915 e_1_3_1 + 8.81 e_1_4_1
#  + 8.972 e_1_5_1 + 9.405 e_1_6_1 + 8.522 e_1_7_1 + 7.448 e_1_8_1
#  + 8.435 e_1_9_1 + 8.883 e_2_3_1 + 6.78 e_2_4_1 + 7.236 e_2_5_1
#  + 6.769 e_2_6_1 + 8.748 e_2_7_1 + 8.99 e_2_8_1 + 8.91 e_2_9_1 + 4.629 e_3_4_1
#  + 9.123 e_3_5_1 + 3.844 e_3_6_1 + 6.833 e_3_7_1 + 4.66 e_3_8_1
#  + 7.756 e_3_9_1 + 6.77 e_4_5_1 + 3.833 e_4_6_1 + 9.197 e_4_7_1
#  + 4.639 e_4_8_1 + 7.008 e_4_9_1 + 6.761 e_5_6_1 + 8.976 e_5_7_1
#  + 9.112 e_5_8_1 + 8.066 e_5_9_1 + 7.193 e_6_7_1 + 5.058 e_6_8_1
#  + 7.003 e_6_9_1 + 9.49 e_7_8_1 + 7.362 e_7_9_1 + 7.29 e_8_9_1
#  <= 26.6666666667
#
# _C3: 6.591 e_0_1_2 + 8.182 e_0_2_2 + 9.244 e_0_3_2 + 6.899 e_0_4_2
#  + 9.085 e_0_5_2 + 9.371 e_0_6_2 + 6.435 e_0_7_2 + 7.641 e_0_8_2
#  + 9.514 e_0_9_2 + 9.395 e_1_2_2 + 6.915 e_1_3_2 + 8.81 e_1_4_2
#  + 8.972 e_1_5_2 + 9.405 e_1_6_2 + 8.522 e_1_7_2 + 7.448 e_1_8_2
#  + 8.435 e_1_9_2 + 8.883 e_2_3_2 + 6.78 e_2_4_2 + 7.236 e_2_5_2
#  + 6.769 e_2_6_2 + 8.748 e_2_7_2 + 8.99 e_2_8_2 + 8.91 e_2_9_2 + 4.629 e_3_4_2
#  + 9.123 e_3_5_2 + 3.844 e_3_6_2 + 6.833 e_3_7_2 + 4.66 e_3_8_2
#  + 7.756 e_3_9_2 + 6.77 e_4_5_2 + 3.833 e_4_6_2 + 9.197 e_4_7_2
#  + 4.639 e_4_8_2 + 7.008 e_4_9_2 + 6.761 e_5_6_2 + 8.976 e_5_7_2
#  + 9.112 e_5_8_2 + 8.066 e_5_9_2 + 7.193 e_6_7_2 + 5.058 e_6_8_2
#  + 7.003 e_6_9_2 + 9.49 e_7_8_2 + 7.362 e_7_9_2 + 7.29 e_8_9_2
#  <= 26.6666666667
#
# _C4: v_0_0 + v_0_1 + v_0_2 = 1
#
# _C5: v_1_0 + v_1_1 + v_1_2 = 1
#
# _C6: v_2_0 + v_2_1 + v_2_2 = 1
#
# _C7: v_3_0 + v_3_1 + v_3_2 = 1
#
# _C8: v_4_0 + v_4_1 + v_4_2 = 1
#
# _C9: v_5_0 + v_5_1 + v_5_2 = 1
#
# _C10: v_6_0 + v_6_1 + v_6_2 = 1
#
# _C11: v_7_0 + v_7_1 + v_7_2 = 1
#
# _C12: v_8_0 + v_8_1 + v_8_2 = 1
#
# _C13: v_9_0 + v_9_1 + v_9_2 = 1
#
# _C14: e_0_1_0 - v_0_0 <= 0
#
# _C15: e_0_2_0 - v_0_0 <= 0
#
# _C16: e_0_3_0 - v_0_0 <= 0
#
# _C17: e_0_4_0 - v_0_0 <= 0
#
# _C18: e_0_5_0 - v_0_0 <= 0
#
# _C19: e_0_6_0 - v_0_0 <= 0
#
# _C20: e_0_7_0 - v_0_0 <= 0
#
# _C21: e_0_8_0 - v_0_0 <= 0
#
# _C22: e_0_9_0 - v_0_0 <= 0
#
# _C23: e_1_2_0 - v_1_0 <= 0
#
# _C24: e_1_3_0 - v_1_0 <= 0
#
# _C25: e_1_4_0 - v_1_0 <= 0
#
# _C26: e_1_5_0 - v_1_0 <= 0
#
# _C27: e_1_6_0 - v_1_0 <= 0
#
# _C28: e_1_7_0 - v_1_0 <= 0
#
# _C29: e_1_8_0 - v_1_0 <= 0
#
# _C30: e_1_9_0 - v_1_0 <= 0
#
# _C31: e_2_3_0 - v_2_0 <= 0
#
# _C32: e_2_4_0 - v_2_0 <= 0
#
# _C33: e_2_5_0 - v_2_0 <= 0
#
# _C34: e_2_6_0 - v_2_0 <= 0
#
# _C35: e_2_7_0 - v_2_0 <= 0
#
# _C36: e_2_8_0 - v_2_0 <= 0
#
# _C37: e_2_9_0 - v_2_0 <= 0
#
# _C38: e_3_4_0 - v_3_0 <= 0
#
# _C39: e_3_5_0 - v_3_0 <= 0
#
# _C40: e_3_6_0 - v_3_0 <= 0
#
# _C41: e_3_7_0 - v_3_0 <= 0
#
# _C42: e_3_8_0 - v_3_0 <= 0
#
# _C43: e_3_9_0 - v_3_0 <= 0
#
# _C44: e_4_5_0 - v_4_0 <= 0
#
# _C45: e_4_6_0 - v_4_0 <= 0
#
# _C46: e_4_7_0 - v_4_0 <= 0
#
# _C47: e_4_8_0 - v_4_0 <= 0
#
# _C48: e_4_9_0 - v_4_0 <= 0
#
# _C49: e_5_6_0 - v_5_0 <= 0
#
# _C50: e_5_7_0 - v_5_0 <= 0
#
# _C51: e_5_8_0 - v_5_0 <= 0
#
# _C52: e_5_9_0 - v_5_0 <= 0
#
# _C53: e_6_7_0 - v_6_0 <= 0
#
# _C54: e_6_8_0 - v_6_0 <= 0
#
# _C55: e_6_9_0 - v_6_0 <= 0
#
# _C56: e_7_8_0 - v_7_0 <= 0
#
# _C57: e_7_9_0 - v_7_0 <= 0
#
# _C58: e_8_9_0 - v_8_0 <= 0
#
# _C59: e_0_1_1 - v_0_1 <= 0
#
# _C60: e_0_2_1 - v_0_1 <= 0
#
# _C61: e_0_3_1 - v_0_1 <= 0
#
# _C62: e_0_4_1 - v_0_1 <= 0
#
# _C63: e_0_5_1 - v_0_1 <= 0
#
# _C64: e_0_6_1 - v_0_1 <= 0
#
# _C65: e_0_7_1 - v_0_1 <= 0
#
# _C66: e_0_8_1 - v_0_1 <= 0
#
# _C67: e_0_9_1 - v_0_1 <= 0
#
# _C68: e_1_2_1 - v_1_1 <= 0
#
# _C69: e_1_3_1 - v_1_1 <= 0
#
# _C70: e_1_4_1 - v_1_1 <= 0
#
# _C71: e_1_5_1 - v_1_1 <= 0
#
# _C72: e_1_6_1 - v_1_1 <= 0
#
# _C73: e_1_7_1 - v_1_1 <= 0
#
# _C74: e_1_8_1 - v_1_1 <= 0
#
# _C75: e_1_9_1 - v_1_1 <= 0
#
# _C76: e_2_3_1 - v_2_1 <= 0
#
# _C77: e_2_4_1 - v_2_1 <= 0
#
# _C78: e_2_5_1 - v_2_1 <= 0
#
# _C79: e_2_6_1 - v_2_1 <= 0
#
# _C80: e_2_7_1 - v_2_1 <= 0
#
# _C81: e_2_8_1 - v_2_1 <= 0
#
# _C82: e_2_9_1 - v_2_1 <= 0
#
# _C83: e_3_4_1 - v_3_1 <= 0
#
# _C84: e_3_5_1 - v_3_1 <= 0
#
# _C85: e_3_6_1 - v_3_1 <= 0
#
# _C86: e_3_7_1 - v_3_1 <= 0
#
# _C87: e_3_8_1 - v_3_1 <= 0
#
# _C88: e_3_9_1 - v_3_1 <= 0
#
# _C89: e_4_5_1 - v_4_1 <= 0
#
# _C90: e_4_6_1 - v_4_1 <= 0
#
# _C91: e_4_7_1 - v_4_1 <= 0
#
# _C92: e_4_8_1 - v_4_1 <= 0
#
# _C93: e_4_9_1 - v_4_1 <= 0
#
# _C94: e_5_6_1 - v_5_1 <= 0
#
# _C95: e_5_7_1 - v_5_1 <= 0
#
# _C96: e_5_8_1 - v_5_1 <= 0
#
# _C97: e_5_9_1 - v_5_1 <= 0
#
# _C98: e_6_7_1 - v_6_1 <= 0
#
# _C99: e_6_8_1 - v_6_1 <= 0
#
# _C100: e_6_9_1 - v_6_1 <= 0
#
# _C101: e_7_8_1 - v_7_1 <= 0
#
# _C102: e_7_9_1 - v_7_1 <= 0
#
# _C103: e_8_9_1 - v_8_1 <= 0
#
# _C104: e_0_1_2 - v_0_2 <= 0
#
# _C105: e_0_2_2 - v_0_2 <= 0
#
# _C106: e_0_3_2 - v_0_2 <= 0
#
# _C107: e_0_4_2 - v_0_2 <= 0
#
# _C108: e_0_5_2 - v_0_2 <= 0
#
# _C109: e_0_6_2 - v_0_2 <= 0
#
# _C110: e_0_7_2 - v_0_2 <= 0
#
# _C111: e_0_8_2 - v_0_2 <= 0
#
# _C112: e_0_9_2 - v_0_2 <= 0
#
# _C113: e_1_2_2 - v_1_2 <= 0
#
# _C114: e_1_3_2 - v_1_2 <= 0
#
# _C115: e_1_4_2 - v_1_2 <= 0
#
# _C116: e_1_5_2 - v_1_2 <= 0
#
# _C117: e_1_6_2 - v_1_2 <= 0
#
# _C118: e_1_7_2 - v_1_2 <= 0
#
# _C119: e_1_8_2 - v_1_2 <= 0
#
# _C120: e_1_9_2 - v_1_2 <= 0
#
# _C121: e_2_3_2 - v_2_2 <= 0
#
# _C122: e_2_4_2 - v_2_2 <= 0
#
# _C123: e_2_5_2 - v_2_2 <= 0
#
# _C124: e_2_6_2 - v_2_2 <= 0
#
# _C125: e_2_7_2 - v_2_2 <= 0
#
# _C126: e_2_8_2 - v_2_2 <= 0
#
# _C127: e_2_9_2 - v_2_2 <= 0
#
# _C128: e_3_4_2 - v_3_2 <= 0
#
# _C129: e_3_5_2 - v_3_2 <= 0
#
# _C130: e_3_6_2 - v_3_2 <= 0
#
# _C131: e_3_7_2 - v_3_2 <= 0
#
# _C132: e_3_8_2 - v_3_2 <= 0
#
# _C133: e_3_9_2 - v_3_2 <= 0
#
# _C134: e_4_5_2 - v_4_2 <= 0
#
# _C135: e_4_6_2 - v_4_2 <= 0
#
# _C136: e_4_7_2 - v_4_2 <= 0
#
# _C137: e_4_8_2 - v_4_2 <= 0
#
# _C138: e_4_9_2 - v_4_2 <= 0
#
# _C139: e_5_6_2 - v_5_2 <= 0
#
# _C140: e_5_7_2 - v_5_2 <= 0
#
# _C141: e_5_8_2 - v_5_2 <= 0
#
# _C142: e_5_9_2 - v_5_2 <= 0
#
# _C143: e_6_7_2 - v_6_2 <= 0
#
# _C144: e_6_8_2 - v_6_2 <= 0
#
# _C145: e_6_9_2 - v_6_2 <= 0
#
# _C146: e_7_8_2 - v_7_2 <= 0
#
# _C147: e_7_9_2 - v_7_2 <= 0
#
# _C148: e_8_9_2 - v_8_2 <= 0
#
# _C149: e_0_1_0 - v_1_0 <= 0
#
# _C150: e_0_2_0 - v_2_0 <= 0
#
# _C151: e_0_3_0 - v_3_0 <= 0
#
# _C152: e_0_4_0 - v_4_0 <= 0
#
# _C153: e_0_5_0 - v_5_0 <= 0
#
# _C154: e_0_6_0 - v_6_0 <= 0
#
# _C155: e_0_7_0 - v_7_0 <= 0
#
# _C156: e_0_8_0 - v_8_0 <= 0
#
# _C157: e_0_9_0 - v_9_0 <= 0
#
# _C158: e_1_2_0 - v_2_0 <= 0
#
# _C159: e_1_3_0 - v_3_0 <= 0
#
# _C160: e_1_4_0 - v_4_0 <= 0
#
# _C161: e_1_5_0 - v_5_0 <= 0
#
# _C162: e_1_6_0 - v_6_0 <= 0
#
# _C163: e_1_7_0 - v_7_0 <= 0
#
# _C164: e_1_8_0 - v_8_0 <= 0
#
# _C165: e_1_9_0 - v_9_0 <= 0
#
# _C166: e_2_3_0 - v_3_0 <= 0
#
# _C167: e_2_4_0 - v_4_0 <= 0
#
# _C168: e_2_5_0 - v_5_0 <= 0
#
# _C169: e_2_6_0 - v_6_0 <= 0
#
# _C170: e_2_7_0 - v_7_0 <= 0
#
# _C171: e_2_8_0 - v_8_0 <= 0
#
# _C172: e_2_9_0 - v_9_0 <= 0
#
# _C173: e_3_4_0 - v_4_0 <= 0
#
# _C174: e_3_5_0 - v_5_0 <= 0
#
# _C175: e_3_6_0 - v_6_0 <= 0
#
# _C176: e_3_7_0 - v_7_0 <= 0
#
# _C177: e_3_8_0 - v_8_0 <= 0
#
# _C178: e_3_9_0 - v_9_0 <= 0
#
# _C179: e_4_5_0 - v_5_0 <= 0
#
# _C180: e_4_6_0 - v_6_0 <= 0
#
# _C181: e_4_7_0 - v_7_0 <= 0
#
# _C182: e_4_8_0 - v_8_0 <= 0
#
# _C183: e_4_9_0 - v_9_0 <= 0
#
# _C184: e_5_6_0 - v_6_0 <= 0
#
# _C185: e_5_7_0 - v_7_0 <= 0
#
# _C186: e_5_8_0 - v_8_0 <= 0
#
# _C187: e_5_9_0 - v_9_0 <= 0
#
# _C188: e_6_7_0 - v_7_0 <= 0
#
# _C189: e_6_8_0 - v_8_0 <= 0
#
# _C190: e_6_9_0 - v_9_0 <= 0
#
# _C191: e_7_8_0 - v_8_0 <= 0
#
# _C192: e_7_9_0 - v_9_0 <= 0
#
# _C193: e_8_9_0 - v_9_0 <= 0
#
# _C194: e_0_1_1 - v_1_1 <= 0
#
# _C195: e_0_2_1 - v_2_1 <= 0
#
# _C196: e_0_3_1 - v_3_1 <= 0
#
# _C197: e_0_4_1 - v_4_1 <= 0
#
# _C198: e_0_5_1 - v_5_1 <= 0
#
# _C199: e_0_6_1 - v_6_1 <= 0
#
# _C200: e_0_7_1 - v_7_1 <= 0
#
# _C201: e_0_8_1 - v_8_1 <= 0
#
# _C202: e_0_9_1 - v_9_1 <= 0
#
# _C203: e_1_2_1 - v_2_1 <= 0
#
# _C204: e_1_3_1 - v_3_1 <= 0
#
# _C205: e_1_4_1 - v_4_1 <= 0
#
# _C206: e_1_5_1 - v_5_1 <= 0
#
# _C207: e_1_6_1 - v_6_1 <= 0
#
# _C208: e_1_7_1 - v_7_1 <= 0
#
# _C209: e_1_8_1 - v_8_1 <= 0
#
# _C210: e_1_9_1 - v_9_1 <= 0
#
# _C211: e_2_3_1 - v_3_1 <= 0
#
# _C212: e_2_4_1 - v_4_1 <= 0
#
# _C213: e_2_5_1 - v_5_1 <= 0
#
# _C214: e_2_6_1 - v_6_1 <= 0
#
# _C215: e_2_7_1 - v_7_1 <= 0
#
# _C216: e_2_8_1 - v_8_1 <= 0
#
# _C217: e_2_9_1 - v_9_1 <= 0
#
# _C218: e_3_4_1 - v_4_1 <= 0
#
# _C219: e_3_5_1 - v_5_1 <= 0
#
# _C220: e_3_6_1 - v_6_1 <= 0
#
# _C221: e_3_7_1 - v_7_1 <= 0
#
# _C222: e_3_8_1 - v_8_1 <= 0
#
# _C223: e_3_9_1 - v_9_1 <= 0
#
# _C224: e_4_5_1 - v_5_1 <= 0
#
# _C225: e_4_6_1 - v_6_1 <= 0
#
# _C226: e_4_7_1 - v_7_1 <= 0
#
# _C227: e_4_8_1 - v_8_1 <= 0
#
# _C228: e_4_9_1 - v_9_1 <= 0
#
# _C229: e_5_6_1 - v_6_1 <= 0
#
# _C230: e_5_7_1 - v_7_1 <= 0
#
# _C231: e_5_8_1 - v_8_1 <= 0
#
# _C232: e_5_9_1 - v_9_1 <= 0
#
# _C233: e_6_7_1 - v_7_1 <= 0
#
# _C234: e_6_8_1 - v_8_1 <= 0
#
# _C235: e_6_9_1 - v_9_1 <= 0
#
# _C236: e_7_8_1 - v_8_1 <= 0
#
# _C237: e_7_9_1 - v_9_1 <= 0
#
# _C238: e_8_9_1 - v_9_1 <= 0
#
# _C239: e_0_1_2 - v_1_2 <= 0
#
# _C240: e_0_2_2 - v_2_2 <= 0
#
# _C241: e_0_3_2 - v_3_2 <= 0
#
# _C242: e_0_4_2 - v_4_2 <= 0
#
# _C243: e_0_5_2 - v_5_2 <= 0
#
# _C244: e_0_6_2 - v_6_2 <= 0
#
# _C245: e_0_7_2 - v_7_2 <= 0
#
# _C246: e_0_8_2 - v_8_2 <= 0
#
# _C247: e_0_9_2 - v_9_2 <= 0
#
# _C248: e_1_2_2 - v_2_2 <= 0
#
# _C249: e_1_3_2 - v_3_2 <= 0
#
# _C250: e_1_4_2 - v_4_2 <= 0
#
# _C251: e_1_5_2 - v_5_2 <= 0
#
# _C252: e_1_6_2 - v_6_2 <= 0
#
# _C253: e_1_7_2 - v_7_2 <= 0
#
# _C254: e_1_8_2 - v_8_2 <= 0
#
# _C255: e_1_9_2 - v_9_2 <= 0
#
# _C256: e_2_3_2 - v_3_2 <= 0
#
# _C257: e_2_4_2 - v_4_2 <= 0
#
# _C258: e_2_5_2 - v_5_2 <= 0
#
# _C259: e_2_6_2 - v_6_2 <= 0
#
# _C260: e_2_7_2 - v_7_2 <= 0
#
# _C261: e_2_8_2 - v_8_2 <= 0
#
# _C262: e_2_9_2 - v_9_2 <= 0
#
# _C263: e_3_4_2 - v_4_2 <= 0
#
# _C264: e_3_5_2 - v_5_2 <= 0
#
# _C265: e_3_6_2 - v_6_2 <= 0
#
# _C266: e_3_7_2 - v_7_2 <= 0
#
# _C267: e_3_8_2 - v_8_2 <= 0
#
# _C268: e_3_9_2 - v_9_2 <= 0
#
# _C269: e_4_5_2 - v_5_2 <= 0
#
# _C270: e_4_6_2 - v_6_2 <= 0
#
# _C271: e_4_7_2 - v_7_2 <= 0
#
# _C272: e_4_8_2 - v_8_2 <= 0
#
# _C273: e_4_9_2 - v_9_2 <= 0
#
# _C274: e_5_6_2 - v_6_2 <= 0
#
# _C275: e_5_7_2 - v_7_2 <= 0
#
# _C276: e_5_8_2 - v_8_2 <= 0
#
# _C277: e_5_9_2 - v_9_2 <= 0
#
# _C278: e_6_7_2 - v_7_2 <= 0
#
# _C279: e_6_8_2 - v_8_2 <= 0
#
# _C280: e_6_9_2 - v_9_2 <= 0
#
# _C281: e_7_8_2 - v_8_2 <= 0
#
# _C282: e_7_9_2 - v_9_2 <= 0
#
# _C283: e_8_9_2 - v_9_2 <= 0
#
# _C284: e_0_1_0 - v_0_0 - v_1_0 >= -1
#
# _C285: e_0_2_0 - v_0_0 - v_2_0 >= -1
#
# _C286: e_0_3_0 - v_0_0 - v_3_0 >= -1
#
# _C287: e_0_4_0 - v_0_0 - v_4_0 >= -1
#
# _C288: e_0_5_0 - v_0_0 - v_5_0 >= -1
#
# _C289: e_0_6_0 - v_0_0 - v_6_0 >= -1
#
# _C290: e_0_7_0 - v_0_0 - v_7_0 >= -1
#
# _C291: e_0_8_0 - v_0_0 - v_8_0 >= -1
#
# _C292: e_0_9_0 - v_0_0 - v_9_0 >= -1
#
# _C293: e_1_2_0 - v_1_0 - v_2_0 >= -1
#
# _C294: e_1_3_0 - v_1_0 - v_3_0 >= -1
#
# _C295: e_1_4_0 - v_1_0 - v_4_0 >= -1
#
# _C296: e_1_5_0 - v_1_0 - v_5_0 >= -1
#
# _C297: e_1_6_0 - v_1_0 - v_6_0 >= -1
#
# _C298: e_1_7_0 - v_1_0 - v_7_0 >= -1
#
# _C299: e_1_8_0 - v_1_0 - v_8_0 >= -1
#
# _C300: e_1_9_0 - v_1_0 - v_9_0 >= -1
#
# _C301: e_2_3_0 - v_2_0 - v_3_0 >= -1
#
# _C302: e_2_4_0 - v_2_0 - v_4_0 >= -1
#
# _C303: e_2_5_0 - v_2_0 - v_5_0 >= -1
#
# _C304: e_2_6_0 - v_2_0 - v_6_0 >= -1
#
# _C305: e_2_7_0 - v_2_0 - v_7_0 >= -1
#
# _C306: e_2_8_0 - v_2_0 - v_8_0 >= -1
#
# _C307: e_2_9_0 - v_2_0 - v_9_0 >= -1
#
# _C308: e_3_4_0 - v_3_0 - v_4_0 >= -1
#
# _C309: e_3_5_0 - v_3_0 - v_5_0 >= -1
#
# _C310: e_3_6_0 - v_3_0 - v_6_0 >= -1
#
# _C311: e_3_7_0 - v_3_0 - v_7_0 >= -1
#
# _C312: e_3_8_0 - v_3_0 - v_8_0 >= -1
#
# _C313: e_3_9_0 - v_3_0 - v_9_0 >= -1
#
# _C314: e_4_5_0 - v_4_0 - v_5_0 >= -1
#
# _C315: e_4_6_0 - v_4_0 - v_6_0 >= -1
#
# _C316: e_4_7_0 - v_4_0 - v_7_0 >= -1
#
# _C317: e_4_8_0 - v_4_0 - v_8_0 >= -1
#
# _C318: e_4_9_0 - v_4_0 - v_9_0 >= -1
#
# _C319: e_5_6_0 - v_5_0 - v_6_0 >= -1
#
# _C320: e_5_7_0 - v_5_0 - v_7_0 >= -1
#
# _C321: e_5_8_0 - v_5_0 - v_8_0 >= -1
#
# _C322: e_5_9_0 - v_5_0 - v_9_0 >= -1
#
# _C323: e_6_7_0 - v_6_0 - v_7_0 >= -1
#
# _C324: e_6_8_0 - v_6_0 - v_8_0 >= -1
#
# _C325: e_6_9_0 - v_6_0 - v_9_0 >= -1
#
# _C326: e_7_8_0 - v_7_0 - v_8_0 >= -1
#
# _C327: e_7_9_0 - v_7_0 - v_9_0 >= -1
#
# _C328: e_8_9_0 - v_8_0 - v_9_0 >= -1
#
# _C329: e_0_1_1 - v_0_1 - v_1_1 >= -1
#
# _C330: e_0_2_1 - v_0_1 - v_2_1 >= -1
#
# _C331: e_0_3_1 - v_0_1 - v_3_1 >= -1
#
# _C332: e_0_4_1 - v_0_1 - v_4_1 >= -1
#
# _C333: e_0_5_1 - v_0_1 - v_5_1 >= -1
#
# _C334: e_0_6_1 - v_0_1 - v_6_1 >= -1
#
# _C335: e_0_7_1 - v_0_1 - v_7_1 >= -1
#
# _C336: e_0_8_1 - v_0_1 - v_8_1 >= -1
#
# _C337: e_0_9_1 - v_0_1 - v_9_1 >= -1
#
# _C338: e_1_2_1 - v_1_1 - v_2_1 >= -1
#
# _C339: e_1_3_1 - v_1_1 - v_3_1 >= -1
#
# _C340: e_1_4_1 - v_1_1 - v_4_1 >= -1
#
# _C341: e_1_5_1 - v_1_1 - v_5_1 >= -1
#
# _C342: e_1_6_1 - v_1_1 - v_6_1 >= -1
#
# _C343: e_1_7_1 - v_1_1 - v_7_1 >= -1
#
# _C344: e_1_8_1 - v_1_1 - v_8_1 >= -1
#
# _C345: e_1_9_1 - v_1_1 - v_9_1 >= -1
#
# _C346: e_2_3_1 - v_2_1 - v_3_1 >= -1
#
# _C347: e_2_4_1 - v_2_1 - v_4_1 >= -1
#
# _C348: e_2_5_1 - v_2_1 - v_5_1 >= -1
#
# _C349: e_2_6_1 - v_2_1 - v_6_1 >= -1
#
# _C350: e_2_7_1 - v_2_1 - v_7_1 >= -1
#
# _C351: e_2_8_1 - v_2_1 - v_8_1 >= -1
#
# _C352: e_2_9_1 - v_2_1 - v_9_1 >= -1
#
# _C353: e_3_4_1 - v_3_1 - v_4_1 >= -1
#
# _C354: e_3_5_1 - v_3_1 - v_5_1 >= -1
#
# _C355: e_3_6_1 - v_3_1 - v_6_1 >= -1
#
# _C356: e_3_7_1 - v_3_1 - v_7_1 >= -1
#
# _C357: e_3_8_1 - v_3_1 - v_8_1 >= -1
#
# _C358: e_3_9_1 - v_3_1 - v_9_1 >= -1
#
# _C359: e_4_5_1 - v_4_1 - v_5_1 >= -1
#
# _C360: e_4_6_1 - v_4_1 - v_6_1 >= -1
#
# _C361: e_4_7_1 - v_4_1 - v_7_1 >= -1
#
# _C362: e_4_8_1 - v_4_1 - v_8_1 >= -1
#
# _C363: e_4_9_1 - v_4_1 - v_9_1 >= -1
#
# _C364: e_5_6_1 - v_5_1 - v_6_1 >= -1
#
# _C365: e_5_7_1 - v_5_1 - v_7_1 >= -1
#
# _C366: e_5_8_1 - v_5_1 - v_8_1 >= -1
#
# _C367: e_5_9_1 - v_5_1 - v_9_1 >= -1
#
# _C368: e_6_7_1 - v_6_1 - v_7_1 >= -1
#
# _C369: e_6_8_1 - v_6_1 - v_8_1 >= -1
#
# _C370: e_6_9_1 - v_6_1 - v_9_1 >= -1
#
# _C371: e_7_8_1 - v_7_1 - v_8_1 >= -1
#
# _C372: e_7_9_1 - v_7_1 - v_9_1 >= -1
#
# _C373: e_8_9_1 - v_8_1 - v_9_1 >= -1
#
# _C374: e_0_1_2 - v_0_2 - v_1_2 >= -1
#
# _C375: e_0_2_2 - v_0_2 - v_2_2 >= -1
#
# _C376: e_0_3_2 - v_0_2 - v_3_2 >= -1
#
# _C377: e_0_4_2 - v_0_2 - v_4_2 >= -1
#
# _C378: e_0_5_2 - v_0_2 - v_5_2 >= -1
#
# _C379: e_0_6_2 - v_0_2 - v_6_2 >= -1
#
# _C380: e_0_7_2 - v_0_2 - v_7_2 >= -1
#
# _C381: e_0_8_2 - v_0_2 - v_8_2 >= -1
#
# _C382: e_0_9_2 - v_0_2 - v_9_2 >= -1
#
# _C383: e_1_2_2 - v_1_2 - v_2_2 >= -1
#
# _C384: e_1_3_2 - v_1_2 - v_3_2 >= -1
#
# _C385: e_1_4_2 - v_1_2 - v_4_2 >= -1
#
# _C386: e_1_5_2 - v_1_2 - v_5_2 >= -1
#
# _C387: e_1_6_2 - v_1_2 - v_6_2 >= -1
#
# _C388: e_1_7_2 - v_1_2 - v_7_2 >= -1
#
# _C389: e_1_8_2 - v_1_2 - v_8_2 >= -1
#
# _C390: e_1_9_2 - v_1_2 - v_9_2 >= -1
#
# _C391: e_2_3_2 - v_2_2 - v_3_2 >= -1
#
# _C392: e_2_4_2 - v_2_2 - v_4_2 >= -1
#
# _C393: e_2_5_2 - v_2_2 - v_5_2 >= -1
#
# _C394: e_2_6_2 - v_2_2 - v_6_2 >= -1
#
# _C395: e_2_7_2 - v_2_2 - v_7_2 >= -1
#
# _C396: e_2_8_2 - v_2_2 - v_8_2 >= -1
#
# _C397: e_2_9_2 - v_2_2 - v_9_2 >= -1
#
# _C398: e_3_4_2 - v_3_2 - v_4_2 >= -1
#
# _C399: e_3_5_2 - v_3_2 - v_5_2 >= -1
#
# _C400: e_3_6_2 - v_3_2 - v_6_2 >= -1
#
# _C401: e_3_7_2 - v_3_2 - v_7_2 >= -1
#
# _C402: e_3_8_2 - v_3_2 - v_8_2 >= -1
#
# _C403: e_3_9_2 - v_3_2 - v_9_2 >= -1
#
# _C404: e_4_5_2 - v_4_2 - v_5_2 >= -1
#
# _C405: e_4_6_2 - v_4_2 - v_6_2 >= -1
#
# _C406: e_4_7_2 - v_4_2 - v_7_2 >= -1
#
# _C407: e_4_8_2 - v_4_2 - v_8_2 >= -1
#
# _C408: e_4_9_2 - v_4_2 - v_9_2 >= -1
#
# _C409: e_5_6_2 - v_5_2 - v_6_2 >= -1
#
# _C410: e_5_7_2 - v_5_2 - v_7_2 >= -1
#
# _C411: e_5_8_2 - v_5_2 - v_8_2 >= -1
#
# _C412: e_5_9_2 - v_5_2 - v_9_2 >= -1
#
# _C413: e_6_7_2 - v_6_2 - v_7_2 >= -1
#
# _C414: e_6_8_2 - v_6_2 - v_8_2 >= -1
#
# _C415: e_6_9_2 - v_6_2 - v_9_2 >= -1
#
# _C416: e_7_8_2 - v_7_2 - v_8_2 >= -1
#
# _C417: e_7_9_2 - v_7_2 - v_9_2 >= -1
#
# _C418: e_8_9_2 - v_8_2 - v_9_2 >= -1
#
# VARIABLES
# 0 <= e_0_1_0 <= 1 Integer
# 0 <= e_0_1_1 <= 1 Integer
# 0 <= e_0_1_2 <= 1 Integer
# 0 <= e_0_2_0 <= 1 Integer
# 0 <= e_0_2_1 <= 1 Integer
# 0 <= e_0_2_2 <= 1 Integer
# 0 <= e_0_3_0 <= 1 Integer
# 0 <= e_0_3_1 <= 1 Integer
# 0 <= e_0_3_2 <= 1 Integer
# 0 <= e_0_4_0 <= 1 Integer
# 0 <= e_0_4_1 <= 1 Integer
# 0 <= e_0_4_2 <= 1 Integer
# 0 <= e_0_5_0 <= 1 Integer
# 0 <= e_0_5_1 <= 1 Integer
# 0 <= e_0_5_2 <= 1 Integer
# 0 <= e_0_6_0 <= 1 Integer
# 0 <= e_0_6_1 <= 1 Integer
# 0 <= e_0_6_2 <= 1 Integer
# 0 <= e_0_7_0 <= 1 Integer
# 0 <= e_0_7_1 <= 1 Integer
# 0 <= e_0_7_2 <= 1 Integer
# 0 <= e_0_8_0 <= 1 Integer
# 0 <= e_0_8_1 <= 1 Integer
# 0 <= e_0_8_2 <= 1 Integer
# 0 <= e_0_9_0 <= 1 Integer
# 0 <= e_0_9_1 <= 1 Integer
# 0 <= e_0_9_2 <= 1 Integer
# 0 <= e_1_2_0 <= 1 Integer
# 0 <= e_1_2_1 <= 1 Integer
# 0 <= e_1_2_2 <= 1 Integer
# 0 <= e_1_3_0 <= 1 Integer
# 0 <= e_1_3_1 <= 1 Integer
# 0 <= e_1_3_2 <= 1 Integer
# 0 <= e_1_4_0 <= 1 Integer
# 0 <= e_1_4_1 <= 1 Integer
# 0 <= e_1_4_2 <= 1 Integer
# 0 <= e_1_5_0 <= 1 Integer
# 0 <= e_1_5_1 <= 1 Integer
# 0 <= e_1_5_2 <= 1 Integer
# 0 <= e_1_6_0 <= 1 Integer
# 0 <= e_1_6_1 <= 1 Integer
# 0 <= e_1_6_2 <= 1 Integer
# 0 <= e_1_7_0 <= 1 Integer
# 0 <= e_1_7_1 <= 1 Integer
# 0 <= e_1_7_2 <= 1 Integer
# 0 <= e_1_8_0 <= 1 Integer
# 0 <= e_1_8_1 <= 1 Integer
# 0 <= e_1_8_2 <= 1 Integer
# 0 <= e_1_9_0 <= 1 Integer
# 0 <= e_1_9_1 <= 1 Integer
# 0 <= e_1_9_2 <= 1 Integer
# 0 <= e_2_3_0 <= 1 Integer
# 0 <= e_2_3_1 <= 1 Integer
# 0 <= e_2_3_2 <= 1 Integer
# 0 <= e_2_4_0 <= 1 Integer
# 0 <= e_2_4_1 <= 1 Integer
# 0 <= e_2_4_2 <= 1 Integer
# 0 <= e_2_5_0 <= 1 Integer
# 0 <= e_2_5_1 <= 1 Integer
# 0 <= e_2_5_2 <= 1 Integer
# 0 <= e_2_6_0 <= 1 Integer
# 0 <= e_2_6_1 <= 1 Integer
# 0 <= e_2_6_2 <= 1 Integer
# 0 <= e_2_7_0 <= 1 Integer
# 0 <= e_2_7_1 <= 1 Integer
# 0 <= e_2_7_2 <= 1 Integer
# 0 <= e_2_8_0 <= 1 Integer
# 0 <= e_2_8_1 <= 1 Integer
# 0 <= e_2_8_2 <= 1 Integer
# 0 <= e_2_9_0 <= 1 Integer
# 0 <= e_2_9_1 <= 1 Integer
# 0 <= e_2_9_2 <= 1 Integer
# 0 <= e_3_4_0 <= 1 Integer
# 0 <= e_3_4_1 <= 1 Integer
# 0 <= e_3_4_2 <= 1 Integer
# 0 <= e_3_5_0 <= 1 Integer
# 0 <= e_3_5_1 <= 1 Integer
# 0 <= e_3_5_2 <= 1 Integer
# 0 <= e_3_6_0 <= 1 Integer
# 0 <= e_3_6_1 <= 1 Integer
# 0 <= e_3_6_2 <= 1 Integer
# 0 <= e_3_7_0 <= 1 Integer
# 0 <= e_3_7_1 <= 1 Integer
# 0 <= e_3_7_2 <= 1 Integer
# 0 <= e_3_8_0 <= 1 Integer
# 0 <= e_3_8_1 <= 1 Integer
# 0 <= e_3_8_2 <= 1 Integer
# 0 <= e_3_9_0 <= 1 Integer
# 0 <= e_3_9_1 <= 1 Integer
# 0 <= e_3_9_2 <= 1 Integer
# 0 <= e_4_5_0 <= 1 Integer
# 0 <= e_4_5_1 <= 1 Integer
# 0 <= e_4_5_2 <= 1 Integer
# 0 <= e_4_6_0 <= 1 Integer
# 0 <= e_4_6_1 <= 1 Integer
# 0 <= e_4_6_2 <= 1 Integer
# 0 <= e_4_7_0 <= 1 Integer
# 0 <= e_4_7_1 <= 1 Integer
# 0 <= e_4_7_2 <= 1 Integer
# 0 <= e_4_8_0 <= 1 Integer
# 0 <= e_4_8_1 <= 1 Integer
# 0 <= e_4_8_2 <= 1 Integer
# 0 <= e_4_9_0 <= 1 Integer
# 0 <= e_4_9_1 <= 1 Integer
# 0 <= e_4_9_2 <= 1 Integer
# 0 <= e_5_6_0 <= 1 Integer
# 0 <= e_5_6_1 <= 1 Integer
# 0 <= e_5_6_2 <= 1 Integer
# 0 <= e_5_7_0 <= 1 Integer
# 0 <= e_5_7_1 <= 1 Integer
# 0 <= e_5_7_2 <= 1 Integer
# 0 <= e_5_8_0 <= 1 Integer
# 0 <= e_5_8_1 <= 1 Integer
# 0 <= e_5_8_2 <= 1 Integer
# 0 <= e_5_9_0 <= 1 Integer
# 0 <= e_5_9_1 <= 1 Integer
# 0 <= e_5_9_2 <= 1 Integer
# 0 <= e_6_7_0 <= 1 Integer
# 0 <= e_6_7_1 <= 1 Integer
# 0 <= e_6_7_2 <= 1 Integer
# 0 <= e_6_8_0 <= 1 Integer
# 0 <= e_6_8_1 <= 1 Integer
# 0 <= e_6_8_2 <= 1 Integer
# 0 <= e_6_9_0 <= 1 Integer
# 0 <= e_6_9_1 <= 1 Integer
# 0 <= e_6_9_2 <= 1 Integer
# 0 <= e_7_8_0 <= 1 Integer
# 0 <= e_7_8_1 <= 1 Integer
# 0 <= e_7_8_2 <= 1 Integer
# 0 <= e_7_9_0 <= 1 Integer
# 0 <= e_7_9_1 <= 1 Integer
# 0 <= e_7_9_2 <= 1 Integer
# 0 <= e_8_9_0 <= 1 Integer
# 0 <= e_8_9_1 <= 1 Integer
# 0 <= e_8_9_2 <= 1 Integer
# 0 <= v_0_0 <= 1 Integer
# 0 <= v_0_1 <= 1 Integer
# 0 <= v_0_2 <= 1 Integer
# 0 <= v_1_0 <= 1 Integer
# 0 <= v_1_1 <= 1 Integer
# 0 <= v_1_2 <= 1 Integer
# 0 <= v_2_0 <= 1 Integer
# 0 <= v_2_1 <= 1 Integer
# 0 <= v_2_2 <= 1 Integer
# 0 <= v_3_0 <= 1 Integer
# 0 <= v_3_1 <= 1 Integer
# 0 <= v_3_2 <= 1 Integer
# 0 <= v_4_0 <= 1 Integer
# 0 <= v_4_1 <= 1 Integer
# 0 <= v_4_2 <= 1 Integer
# 0 <= v_5_0 <= 1 Integer
# 0 <= v_5_1 <= 1 Integer
# 0 <= v_5_2 <= 1 Integer
# 0 <= v_6_0 <= 1 Integer
# 0 <= v_6_1 <= 1 Integer
# 0 <= v_6_2 <= 1 Integer
# 0 <= v_7_0 <= 1 Integer
# 0 <= v_7_1 <= 1 Integer
# 0 <= v_7_2 <= 1 Integer
# 0 <= v_8_0 <= 1 Integer
# 0 <= v_8_1 <= 1 Integer
# 0 <= v_8_2 <= 1 Integer
# 0 <= v_9_0 <= 1 Integer
# 0 <= v_9_1 <= 1 Integer
# 0 <= v_9_2 <= 1 Integer

# %%
prob.solve(solver)
# Out:
# 1

# %%
for v in prob.variables()[len(prob.variables()) - n*K : len(prob.variables())]:
    print(v.name, "=", v.varValue)
# Out:
# v_0_0 = 0.0
# v_0_1 = 1.0
# v_0_2 = 0.0
# v_1_0 = 0.0
# v_1_1 = 0.0
# v_1_2 = 1.0
# v_2_0 = 0.0
# v_2_1 = 1.0
# v_2_2 = 0.0
# v_3_0 = 1.0
# v_3_1 = 0.0
# v_3_2 = 0.0
# v_4_0 = 1.0
# v_4_1 = 0.0
# v_4_2 = 0.0
# v_5_0 = 0.0
# v_5_1 = 1.0
# v_5_2 = 0.0
# v_6_0 = 1.0
# v_6_1 = 0.0
# v_6_2 = 0.0
# v_7_0 = 0.0
# v_7_1 = 0.0
# v_7_2 = 1.0
# v_8_0 = 1.0
# v_8_1 = 0.0
# v_8_2 = 0.0
# v_9_0 = 0.0
# v_9_1 = 0.0
# v_9_2 = 1.0

# %%
pairs = prob.variables()[0: len(prob.variables()) - n*K]
people_values = [v.varValue for v in pairs] 
np.sum(np.multiply(people_values, happiness))
# Out:
# 75.0

# %%
sum(people_values)
# Out:
# 12.0

# %% [markdown]
# # Gurobi

# %%
### Continuous 

inputs = pd.read_csv("phase1/20.in", header = None)
n = int(list(inputs[0])[0])
s_max = float(list(inputs[0])[1])
K = 5

# Parsing input data 
df = inputs
df = pd.DataFrame([x.split() for x in df[0].tolist() ])
df = df.loc[2:,:]
df["i"] = df.loc[:,0]
df["j"] = df.loc[:,1]
df["sadness"] = df.loc[:,3]
df["happiness"] = df.loc[:,2]
df = df[["i", "j", "sadness", "happiness"]]

i_id = [int(i) for i in list(df["i"])]
j_id = [int(i) for i in list(df["j"])]
sadness = [float(i) for i in list(df["sadness"])]*K
happiness = [float(i) for i in list(df["happiness"])]*K

sadness_1 = [float(i) for i in list(df["sadness"])]
happiness_1 = [float(i) for i in list(df["happiness"])]
len(sadness) == len(happiness)

m = gp.Model("proj")
m.setParam('OutputFlag', 0)

# Some stuff

d_e = {}
for k in range(K):
    for i in range(comb(n,2)):
        d_e["e_{0}_{1}_{2}".format(i_id[i],j_id[i],k)] = m.addVar(name= "e_{0}_{1}_{2}".format(i_id[i],j_id[i],k), vtype = GRB.BINARY)
edges_1 = list(d_e.values())

# Create another edge array with different sort
edges_2 = [d_e.get(i) for i in sorted(d_e.keys(), key=lambda x: (x[2], x[4]))]

# Create another edge array for constraint 4 
edges_3 = [d_e.get(i) for i in sorted(d_e.keys(), key=lambda x: (x[2], x[6]))]

# Check
print(len(edges_1) == comb(n,2)*K)
     
# vertices 
d_v = {}
for j in range(K):
    for i in range(n):
        d_v["v_{0}_{1}".format(i,j)] = m.addVar(name = "v_{0}_{1}".format(i,j),  vtype = GRB.BINARY)
vertices_1 = list(d_v.values())

# Create another edge array with different sort
# vertices_2 = [d_v.get(i) for i in sorted(d_v.keys(), key=lambda x: x[2])]
vertices_2 = [d_v.get(i) for i in sorted(d_v.keys())]

# Check
print(len(vertices_1) == n*K)

# Linearization of quadratic variables 1 
v_list = np.array(np.array_split(vertices_1, K)).tolist()
v_big = []
for i in range(K):
    j = 0
    while j != n:
        for _ in range(j,n-1):
            v_big.append(v_list[i][j])
        j += 1
        
print(len(edges_1) == len(v_big))

# Linearization of quadratic variables 2
v_list_2 = [i[1:] for i in v_list]
v_big_2 = []
for h in range(K):
    j = 0
    while j != n:
        for i in range(j,n-1):
            v_big_2.append(v_list_2[h][i])
        j += 1
        i = j
print(len(edges_1) == len(v_big_2))

m.setObjective(sum(edges_1[i] * happiness[i] for i in range(len(happiness))), GRB.MAXIMIZE)

aa = []
h = 0
for i in range(K):
    for j in range(comb(n,2)):
        aa.append(edges_1[h] * sadness_1[j])
        h += 1

constraint_2 = [sum(aa[i:i+ comb(n,2)]) for i in range(0, len(aa), comb(n,2))]
for i in range(len(constraint_2)):
    m.addConstr(constraint_2[i] <=  s_max / K)

constraint_3 = [sum(vertices_2[i:i + K]) for i in range(0, len(vertices_2), K)]
for i in range(len(constraint_3)):
    m.addConstr(constraint_3[i] == 1)

# Constraint 4'
for i in range(len(edges_1)):
    m.addConstr(edges_1[i] == v_big[i] * v_big_2[i])

hardlimit = 30
m.setParam('TimeLimit', hardlimit)
m.optimize()

pairs = m.getVars()[0 : len(m.getVars()) - n*K]
people = m.getVars()[len(m.getVars()) - n*K : len(m.getVars())]
people_values = [v.X for v in people]
people_values = np.array_split(people_values, K)
pair_values = [v.X for v in pairs]
np.sum(np.multiply(pair_values, happiness))

output_dict = {}
for k in range(K):
    arr = []
    for i in range(n):
        if people_values[k][i] == 1: 
            arr += [i]
            output_dict[k] = arr

output_dict
# Out:
# True
# True
# True
# True
# {0: [0, 8, 10, 14],
#  1: [1, 2, 12, 13],
#  2: [3, 4, 11, 17],
#  3: [5, 6, 9, 19],
#  4: [7, 15, 16, 18]}

# %%
people
# Out:
# [<gurobi.Var v_0_0 (value 1.0)>,
#  <gurobi.Var v_1_0 (value 0.0)>,
#  <gurobi.Var v_2_0 (value -0.0)>,
#  <gurobi.Var v_3_0 (value -0.0)>,
#  <gurobi.Var v_4_0 (value 0.0)>,
#  <gurobi.Var v_5_0 (value 0.0)>,
#  <gurobi.Var v_6_0 (value -0.0)>,
#  <gurobi.Var v_7_0 (value 1.0)>,
#  <gurobi.Var v_8_0 (value 0.0)>,
#  <gurobi.Var v_9_0 (value 0.0)>,
#  <gurobi.Var v_10_0 (value 0.0)>,
#  <gurobi.Var v_11_0 (value -0.0)>,
#  <gurobi.Var v_12_0 (value 0.0)>,
#  <gurobi.Var v_13_0 (value 1.0)>,
#  <gurobi.Var v_14_0 (value 0.0)>,
#  <gurobi.Var v_15_0 (value 1.0)>,
#  <gurobi.Var v_16_0 (value 0.0)>,
#  <gurobi.Var v_17_0 (value -0.0)>,
#  <gurobi.Var v_18_0 (value -0.0)>,
#  <gurobi.Var v_19_0 (value 0.0)>,
#  <gurobi.Var v_0_1 (value -0.0)>,
#  <gurobi.Var v_1_1 (value 0.0)>,
#  <gurobi.Var v_2_1 (value 1.0)>,
#  <gurobi.Var v_3_1 (value -0.0)>,
#  <gurobi.Var v_4_1 (value 0.0)>,
#  <gurobi.Var v_5_1 (value 1.0)>,
#  <gurobi.Var v_6_1 (value -0.0)>,
#  <gurobi.Var v_7_1 (value 0.0)>,
#  <gurobi.Var v_8_1 (value -0.0)>,
#  <gurobi.Var v_9_1 (value 0.0)>,
#  <gurobi.Var v_10_1 (value 1.0)>,
#  <gurobi.Var v_11_1 (value 0.0)>,
#  <gurobi.Var v_12_1 (value 0.0)>,
#  <gurobi.Var v_13_1 (value -0.0)>,
#  <gurobi.Var v_14_1 (value 1.0)>,
#  <gurobi.Var v_15_1 (value 0.0)>,
#  <gurobi.Var v_16_1 (value 0.0)>,
#  <gurobi.Var v_17_1 (value 0.0)>,
#  <gurobi.Var v_18_1 (value 0.0)>,
#  <gurobi.Var v_19_1 (value 0.0)>,
#  <gurobi.Var v_0_2 (value -0.0)>,
#  <gurobi.Var v_1_2 (value 0.0)>,
#  <gurobi.Var v_2_2 (value -0.0)>,
#  <gurobi.Var v_3_2 (value -0.0)>,
#  <gurobi.Var v_4_2 (value 0.0)>,
#  <gurobi.Var v_5_2 (value 0.0)>,
#  <gurobi.Var v_6_2 (value -0.0)>,
#  <gurobi.Var v_7_2 (value 0.0)>,
#  <gurobi.Var v_8_2 (value 0.0)>,
#  <gurobi.Var v_9_2 (value 1.0)>,
#  <gurobi.Var v_10_2 (value 1.0)>,
#  <gurobi.Var v_11_2 (value 0.0)>,
#  <gurobi.Var v_12_2 (value 0.0)>,
#  <gurobi.Var v_13_2 (value -0.0)>,
#  <gurobi.Var v_14_2 (value 1.0)>,
#  <gurobi.Var v_15_2 (value -0.0)>,
#  <gurobi.Var v_16_2 (value 0.0)>,
#  <gurobi.Var v_17_2 (value 1.0)>,
#  <gurobi.Var v_18_2 (value 0.0)>,
#  <gurobi.Var v_19_2 (value -0.0)>,
#  <gurobi.Var v_0_3 (value -0.0)>,
#  <gurobi.Var v_1_3 (value -0.0)>,
#  <gurobi.Var v_2_3 (value -0.0)>,
#  <gurobi.Var v_3_3 (value 0.0)>,
#  <gurobi.Var v_4_3 (value -0.0)>,
#  <gurobi.Var v_5_3 (value 0.0)>,
#  <gurobi.Var v_6_3 (value 1.0)>,
#  <gurobi.Var v_7_3 (value -0.0)>,
#  <gurobi.Var v_8_3 (value 1.0)>,
#  <gurobi.Var v_9_3 (value 0.0)>,
#  <gurobi.Var v_10_3 (value -0.0)>,
#  <gurobi.Var v_11_3 (value 0.0)>,
#  <gurobi.Var v_12_3 (value 0.0)>,
#  <gurobi.Var v_13_3 (value 0.0)>,
#  <gurobi.Var v_14_3 (value 0.0)>,
#  <gurobi.Var v_15_3 (value 1.0)>,
#  <gurobi.Var v_16_3 (value -0.0)>,
#  <gurobi.Var v_17_3 (value 0.0)>,
#  <gurobi.Var v_18_3 (value 1.0)>,
#  <gurobi.Var v_19_3 (value 0.0)>,
#  <gurobi.Var v_0_4 (value 0.0)>,
#  <gurobi.Var v_1_4 (value -0.0)>,
#  <gurobi.Var v_2_4 (value 0.0)>,
#  <gurobi.Var v_3_4 (value 1.0)>,
#  <gurobi.Var v_4_4 (value 1.0)>,
#  <gurobi.Var v_5_4 (value 0.0)>,
#  <gurobi.Var v_6_4 (value 0.0)>,
#  <gurobi.Var v_7_4 (value 0.0)>,
#  <gurobi.Var v_8_4 (value 0.0)>,
#  <gurobi.Var v_9_4 (value 0.0)>,
#  <gurobi.Var v_10_4 (value 0.0)>,
#  <gurobi.Var v_11_4 (value 1.0)>,
#  <gurobi.Var v_12_4 (value 0.0)>,
#  <gurobi.Var v_13_4 (value 0.0)>,
#  <gurobi.Var v_14_4 (value 0.0)>,
#  <gurobi.Var v_15_4 (value 0.0)>,
#  <gurobi.Var v_16_4 (value 0.0)>,
#  <gurobi.Var v_17_4 (value 1.0)>,
#  <gurobi.Var v_18_4 (value 0.0)>,
#  <gurobi.Var v_19_4 (value 0.0)>]

# %%
inputs = pd.read_csv("phase1/test10.in", header = None)
float(list(inputs[0])[1])
# Out:
# 99.0
